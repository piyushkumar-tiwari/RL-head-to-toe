# %% [markdown]
# ### ***SARSA*** ###

# %% [markdown]
# ### ***Q-Learning*** ###

# %%
import numpy as np

class QLearning:
    def __init__(self, states, actions, num_episodes, epsilon = 0.1, beta = 0.5):
        self.states = states
        self.actions = actions
        self.num_episodes = num_episodes
        self.epsilon = epsilon
        self.beta = beta

        q_table = np.zeros(shape=(self.states,self.actions))

# %% [markdown]
# ### ***TD-Learning*** ###

# %% [markdown]
# ### ***Markov Chain Control*** ###

# %% [markdown]
# ### ***Value Iteration*** ###

# %% [markdown]
# ### ***Policy Iteration*** ###
