# %% [markdown]
# ### ***SARSA*** ###

# %% [markdown]
# ### ***Q-Learning*** ###

# %%
import numpy as np

class QLearning:
    def __init__(self, states, actions, num_episodes, epsilon = 0.1, gamma = 0.9, beta = 0.5):
        self.states = np.arange(0, states + 1)
        self.actions = np.arange(0, actions+1)   
        self.num_episodes = num_episodes
        self.epsilon = epsilon
        self.beta = beta
        self.gamma = gamma

        self.q_table = np.zeros(shape=(self.states.size,self.actions.size))

    def choose_action(self, state_index):
        if np.random.uniform(0,1) < self.epsilon:
            return np.random.choice(self.actions)
        else:
            return np.argmax(self.q_table[state_index])
        
    def step (self, action, state, reward, next_state):
        return self.q_table[state,action] + self.beta * (reward + (self.gamma * np.max(self.q_table[next_state,action])) - self.q_table[state, action])

# %% [markdown]
# ### ***TD-Learning*** ###

# %% [markdown]
# ### ***Markov Chain Control*** ###

# %% [markdown]
# ### ***Value Iteration*** ###

# %% [markdown]
# ### ***Policy Iteration*** ###
