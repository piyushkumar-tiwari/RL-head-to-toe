# %% [markdown]
# ## ***Environment Definition*** ##

# %%
import numpy as np

class Airplane:
    def __init__(self, K = 25 ,T = 10, prices = [50, 100, 150, 200, 250]):
        self.time = T
        self.prices = prices
        self.seats_remaining = K
        self.reset()

    def reset(self):
        self.time_left = self.time
        self.seats_remain = self.seats_remaining
        return self._get_state_index()

    def _get_state_index(self):
        return self.seats_remain * (self.T + 1) + self.time_left
    
    def step (self, action_index):
        price = self.prices[action_index]
        avg_demand = 250/price
        demand = np.random.poisson(avg_demand)
        seats_sold = min(self.seats_remaining, demand)
        reward = seats_sold * price
        self.current_seats -= seats_sold
        self.days_left -= 1

        done = (self.days_left == 0) or (self.current_seats == 0)
        return self._get_state_index(), reward, done

# %% [markdown]
# ### ***SARSA*** ###

# %%
import numpy as np

class SARSA:
    def __init__(self,  num_episodes, states, actions, alpha = 0.9, gamma = 0.5, epsilon = 0.1):
        self.states = np.arange(0, states)
        self.actions = np.arange(0,actions)
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.num_episodes = num_episodes
        self.q_table = np.zeros((len(self.states), len(self.actions)))

    def choose_action(self, state_index):
        if np.random.uniform(0,1) < self.epsilon:
            return np.random.choice(self.actions)
        else:
            return np.argmax(self.q_table[state_index])
    
    def doSARSA(self, state, action, next_state, next_action, reward):
        new_q = self.q_table[state, action] + self.alpha * (reward + self.gamma * self.q_table[next_state, next_action] - self.q_table[state, action])
        self.q_table[state, action] = new_q
        return self.q_table
    
    def train(self, env, num_episodes):
        for e in range(self.num_episodes):
            state = env.reset()
            action = self.choose_action(state)
            done = False
            while not done:
                next_state, reward, done = env.step(action)
                next_action = self.choose_action(next_state)

                self.doSARSA(state, action, next_state, next_action, reward)
                state = next_state
                action = next_action
            self.epsilon *= 0.99

# %% [markdown]
# ### ***Q-Learning*** ###

# %%
import numpy as np

class QLearning:
    def __init__(self, states, actions, num_episodes, epsilon = 0.1, gamma = 0.9, beta = 0.5):
        self.states = np.arange(0, states + 1)
        self.actions = np.arange(0, actions+1)   
        self.num_episodes = num_episodes
        self.epsilon = epsilon
        self.beta = beta
        self.gamma = gamma

        self.q_table = np.zeros(shape=(self.states.size,self.actions.size))

    def choose_action(self, state_index):
        if np.random.uniform(0,1) < self.epsilon:
            return np.random.choice(self.actions)
        else:
            return np.argmax(self.q_table[state_index])
        
    def step (self, action, state, reward, next_state):
        new_q = self.q_table[state,action] + self.beta * (reward + (self.gamma * np.max(self.q_table[next_state])) - self.q_table[state, action])
        self.q_table[state,action] = new_q

# %% [markdown]
# ### ***TD-Learning*** ###

# %%
import numpy as np
class TDLearning:
    def __init__(self, states, actions, num_episodes, alpha = 0.5, gamma = 0.9):
        self.actions = actions
        self.states = states
        self.num_episodes = num_episodes
        self.alpha = alpha
        self.gamma = gamma

        self.value_fun = np.zeros(shape=len(self.states))
    
    def doTDL(self, state, next_state, reward):
        if next_state == False:
            v_new = self.value[state] + self.alpha * (reward - self.value_fun[state])
        else:
            v_new = self.value_fun[state] + self.alpha * (reward + (self.gamma * self.value_fun[next_state]) - self.value_fun[state])
        self.value_fun[state] = v_new

    def train(self, env, num_episodes):
        for e in range(num_episodes):
            state = env.reset()
            action = np.random.choice(self.actions)
            done = False

            while not done:
                next_state, reward, done = env.step(action)
                next_action = np.random.choice(next_state)
                self.doTDL(state, next_state, reward)
                state = next_state
                action = next_action

# %% [markdown]
# ### ***Markov Chain Control*** ###

# %% [markdown]
# ### ***Value Iteration*** ###

# %%
import numpy as np

class VI:
    def __init__(self, states, actions, num_episodes, trans_prob, alpha = 0.5, gamma = 0.9):
        self.states = states
        self.actions = actions
        self.num_episodes = num_episodes
        self.trans_prob = trans_prob
        self.alpha = alpha
        self.gamma = gamma
        self.value_fun = np.zeros(shape=(len(self.states)))

        if self.trans_prob is None:
            num_s = len(self.states)
            num_a = len(self.actions)
            raw_prob = np.random.uniform(0,1, size=(num_a, num_s, num_s))
            self.trans_prob = raw_prob/raw_prob.sum(axis=2,keepdims=True)
    
    def DoVI(self, rewards, threshold=1e-6):
        num_s = len(self.states)
        num_a = len(self.actions)

        for i in range(self.num_episodes):
            delta = 0
            v_old = np.copy(self.value_fun)

            for s in range(num_s):
                # Calculate the value for each action from state s
                # Q_sa = Sum over s' of [ P(s'|s,a) * (R + gamma * V(s')) ]
                action_values = []
                for a in range(num_a):
                    # self.trans_prob[a, s, :] gives probabilities for all next states s'
                    v_next = np.sum(self.trans_prob[a, s, :] * (rewards[s, a] + self.gamma * v_old))
                    action_values.append(v_next)
                
                # Update value function with the best action's value
                self.value_fun[s] = max(action_values)
                
                # Track the maximum change to check for convergence
                delta = max(delta, np.abs(v_old[s] - self.value_fun[s]))

            # If the value function barely changed, we've converged!
            if delta < threshold:
                print(f"Converged after {i} iterations.")
                break
        
        return self.value_fun

# %% [markdown]
# ### ***Policy Iteration*** ###
