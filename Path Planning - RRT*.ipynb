# %%
from PIL import Image, ImageOps
import numpy as np
import matplotlib.pyplot as plt

# %%
img = Image.open('/home/piyush/Downloads/simple.jpg')
img = ImageOps.grayscale(img)

np_img = np.array(img)
grid = (np_img < 128).astype(np.uint8)
plt.imshow(grid, cmap='binary')
plt.show()

# %%
class treenode():
    def __init__(self, locx, locy):
        self.locx = locx
        self.locy = locy
        self.children = []
        self.parent = None
class RRT_algo():
    def __init__(self, start, goal, num_iteration, grid, stepsize):
        self.root = treenode(start[0], start[1])
        self.goal = goal
        self.num_iterations = num_iteration
        self.grid = grid
        self.stepsize = stepsize
        self.nearestnode = None
        self.numwaypoints = 0
        self.waypoints = []
        self.nearestdist = 1000
    
    def samplepoint(self):
        x = np.random.randint(0, 1200)
        y = np.random.randint(0, 1200)
        point = np.array([x, y])
        return point
    
    def addchild(self, locx ,locy):
        pass

    def steerToPoint(self, locstart, locend):
        list1 = np.array[0 ,100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]
        if 

    def isInObstacle(self, locstart, locend):
        pass

    def unitvector(self, node, point):
        del = samplepoint()
        x, y = del[0], del[1]
        a, b = node
        dist1 = (x-a)
        dist2 = (y-b)
        root = np.sqrt((dist1**2) + (dist2**2))
        return (dist1 + dist2)/root

    def findnearest(self, root, point):
        pass

    def distance(self, node, point):
        pass

    def goalFound(self, point):
        pass

    def resetNearestValues(self):
        return np.random.random(self.waypoints)

    def retraceRRTPath(self, goal):
        pass
